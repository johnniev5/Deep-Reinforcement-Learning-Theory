# %% [markdown]
# 学徒式教学，收集很多experts的经验...
#
# 方法有：
#
# * behavior cloning
# * inverse reinforcement learning
#
# 可以使用监督式学习，但是这种情况非常limited的，只能处理训练中出现的...
#
# 可以收集更多情况的dataset，但是这情况问题就是收集不同情况的数据，存在困难...
#
# 要让机器知道哪些是需要学习的，哪些是不需要学习的...
#
# 这种方法存在train和testing的mismatch，很难在training时learning到experts的行为...
#
# 另一种方法inverse reinforcement learning
#
# 从experts的datasets，通过inverse reinforcement learning反推出reward function，也就是数experts应该具有的funciton应该是怎样的...
#
# ![inverse%20reinforcement%20learning%201.png](attachment:inverse%20reinforcement%20learning%201.png)
# ![inverse%20reinforcement%20learning%202.png](attachment:inverse%20reinforcement%20learning%202.png)
#
# 假定experts是最好的...
#
# 这个过程更GAN特别像...
#
# ![GAN%20vs%20IRL.png](attachment:GAN%20vs%20IRL.png)
#
# 应用，比如开自驾车...
#
# 从第三人称到第一人称的转换...
#
# ![Third%20Person%20Imitation%20Learning.png](attachment:Third%20Person%20Imitation%20Learning.png)
#
# 强化学习同样可以使用到chat-bot & sentence generation...
#
# ![recap.png](attachment:recap.png)
